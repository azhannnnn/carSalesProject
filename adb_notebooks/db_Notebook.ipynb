# %% [markdown]
# ### CREATE CATALOG

# %%
# %sql

CREATE CATALOG cars_catalog;

USE CATALOG cars_catalog;

# %% [markdown]
# ### CREATE SCHEMAS

# %%
# %sql

CREATE SCHEMA silver;
CREATE SCHEMA gold;
